# %%
from docling.document_converter import DocumentConverter

source = "applsci-3508831-peer-review-v1.pdf"  # document per local path or URL
converter = DocumentConverter()
result = converter.convert(source)
print(result.document.export_to_markdown())  # output: "## Docling Technical Report[...]"
# Out:
# C:\Users\radiu\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# C:\Users\radiu\anaconda3\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: [WinError 127] The specified procedure could not be found
#   warn(f"Failed to load image Python extension: {e}")
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# C:\Users\radiu\anaconda3\lib\site-packages\huggingface_hub\file_download.py:142: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\radiu\.cache\huggingface\hub\models--ds4sd--docling-models. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# <!-- image -->
#
# <!-- image -->
#
# Article
#
# ## Prediction of the use of generative artificial intelligence through ChatGPT among Costa Rican university students: A PLS model based on UTAUT2
#
# Julio Cabero-Almenara 1 , Antonio Palacios-Rodrí guez 1, *, Hazel de los Ángeles Rojas Guzmá n 2  and Victoria Ferná ndez-Scagliusi 1
#
# - 1 University of Seville (Spain), Department of Didactics and Educational Organization
# - 2 University of Costa Rica (Costa Rica), Department of Social Sciences
#
# Academic Editor: Firstname Last-
#
# name
#
# Received: date
#
# Revised: date
#
# Accepted: date
#
# Published: date
#
# Citation: To be added by editorial staff during production.
#
# Copyright: ©  2025 by the authors. Submitted for possible open access publication under the terms and conditions of the Creative Commons Attribution (CC BY) license (https://creativecommons.org/license s/by/4.0/).
#
# Academic Editor: Firstname Last-
#
# name
#
# Received: date
#
# Revised: date
#
# Accepted: date
#
# Published: date
#
# 2
#
# 3
#
# 4
#
# 5
#
# 6
#
# 7
#
# 8
#
# 9
#
# - * Correspondence: aprodriguez@us.es
#
# 10
#
# Abstract: The rise of generative artificial intelligence (GenAI) is transforming education,    11 with tools like ChatGPT enhancing learning, content creation, and academic support. This    12 study analyzes ChatGPT's acceptance among Costa Rican university students using the 13 UTAUT2 model and partial least squares structural equation modeling (PLS-SEM). The    14 research examines key predictors of AI adoption, including performance expectancy, ef15 fort expectancy, social influence, facilitating conditions, behavioral intention, and actual 16 usage. Data from 194 students reveal that performance expectancy is the strongest predic17 tor of behavioral intention, followed by effort expectancy, while social influence and fa18 cilitating conditions play a minor role. Behavioral intention significantly influences actual 19 usage. Differences emerge based on gender and age, with male students and those aged    20 21-30 showing higher acceptance levels. Despite positive attitudes toward ChatGPT, stu21 dents report a lack of sufficient training for its effective use. These findings highlight the 22 need for tailored pedagogical strategies to ensure meaningful AI integration into educa23 tion. The study suggests further research on AI training programs and their long-term    24 impact on academic performance, emphasizing the importance of fostering digital literacy    25 for a more effective and responsible adoption of generative AI in higher education. 26
#
# Keywords: ChatGPT; AI acceptance; UTAUT2; higher education; digital literacy
#
# 27
#
# 28
#
# ## 1. Introduction
#
# 29
#
# 31
#
# 32
#
# 34
#
# 35
#
# 36
#
# 38
#
# 39
#
# 41
#
# The emergence of generative artificial intelligence (GenAI) in the educational field is 30 having a significant impact on teaching practices and students' learning processes. This type of artificial intelligence is characterized by its ability to process natural human language and generate content in various formats, such as text, images, and audio. As [1] (p.    33 2)  points  out,  "generative  models process a large corpus of complex and unstructured data, such as texts, audio, or images, to then generate new content in the same style as the original data." Similarly, [2] (p. 7) states that "it refers to a distinct class of artificial intelligence that uses deep learning models to generate human-like content, such as images or    37 words, in response to complex and varied instructions." This content can be produced in a wide variety of formats (video, text, audio, etc.) and serve different functions (assigning labels  to  images,  clustering  data -such as identifying customer segments with similar    40 purchasing behaviors -or selecting actions) [3].
#
# The use of GenAI in educational contexts has been facilitated by the accessibility of 42 tools based on advanced language models, whose intuitive interface allows interactions    43 through natural language. However, this ease of use does not imply that its educational    44 application is automatically effective. As UNESCO [4] warns, the effective use of these    45 tools requires specific training in both query formulation and the interpretation and refi46 nement of generated responses. In this regard, a transition in the application of technology 47 in teaching is observed: from a model focused on learning "from" technology, where it is 48 perceived merely as a channel for transmitting information and assessment, to a paradigm    49 of learning "with" technology, where its use is enhanced as a cognitive tool for knowledge    50 construction [5]. 51
#
# Despite its growing incorporation into education, the implementation of GenAI pre52 sents various challenges and limitations. Among these, the accuracy and validity of gene53 rated information, ethical responsibility in its use, the need for curricular adaptation, the 54 redefinition of teaching and student roles, and the presence of inherent biases in AI mo55 dels stand out. Additionally, aspects such as randomness in responses, dependence on    56 these tools, the need for specific training to critically evaluate their results, and implica57 tions for data privacy and security must be considered [6, 7, 8]. In this last aspect, there    58 are two major models: in one, control is held by companies, as seen in the United States, 59 while in the other, control is exercised by the state, as in China. 60
#
# Among the most widely used GenAI tools in the educational environment are Ope61 nAI's ChatGPT, Microsoft's Copilot, Deepseek by Hangzhou DeepSeek Artificial Intelli62 gence Basic Technology Research, and Google's Gemini. These platforms offer a wide    63 range of functionalities, including text generation, image creation, document translation, 64 summarization and evaluation rubrics, key idea identification, case correction, assistance 65 in computer programming, and information synthesis, among others. This versatility has    66 made GenAI an attractive resource for integration into teaching, transforming traditional 67 teaching and learning methodologies [9, 10] 68
#
# The rise in the use of GenAI in education has led to an increase in research on its 69 pedagogical applications and has driven meta-analyses on its impact in various educatio70 nal contexts [11, 12, 13, 14, 15]. These systematic reviews have identified key trends, such 71 as the predominance of studies focused on higher education, the concentration of research 72 in developed countries, teachers' concerns about ethical aspects, the interest in analyzing 73 students' practices with these tools, the recognition of their potential for adaptive learning, 74 and the identification of a widespread need for training in their use. Additionally, both 75 teachers and students express a positive attitude toward the incorporation of GenAI in    76 teaching, provided that its use is carried out critically and reflectively [16, 17]. 77
#
# To conclude this section, it is worth highlighting Robert &amp; Muscanell [18] in their    78 Horizon Report for Educause: '… generative artificial intelligence emerged as the fastest -79 adopted technology in history. All members of the higher education community, from    80 students to administrators, are trying to determine what impact generative AI tools can, 81 will, and should have on life, learning, and work.' [18] (p. 3). 82
#
# ## 2. Students and ChatGPT
#
# 83
#
# In this regard, artificial intelligence (AI) represents a field of particular interest, given 84 its exponential growth and increasing integration into teaching and learning processes. 85 Exploring students' attitudes and level of acceptance toward this technology in general, 86 and ChatGPT in particular, not only helps to understand their disposition toward these    87 technologies but is also essential for identifying necessary changes in AI education, the 88 measures that should be adopted to optimize their training in this field, and the possibil89 ities that, according to students, these technologies have for their incorporation into their 90 educational activities. 91
#
# The incorporation of AI into education has been carried out under three paradigms:    92 AI-directed, where the student is a recipient; AI-supported, where the student is a collab93 orator; and AI-empowered, where the student is a leader. In these three paradigms, AI    94 techniques are used to address educational and learning problems in different ways. AI 95 is used to represent knowledge models and guide cognitive learning while students act    96 as recipients of AI services in Paradigm One; AI is used to support learning while students 97 collaborate with AI in Paradigm Two; AI is used to empower learning while students take    98 the initiative to learn in Paradigm Three [19]. 99
#
# Numerous studies have shown that students exhibit positive attitudes and strong    100 interest in the possibilities AI offers for their education, as well as an increasing willing101 ness to integrate these tools into their learning [20, 21, 16, 22, 23]. 102
#
# However, research results have sometimes been contradictory. Some studies indicate    103 that AI use decreases students' academic performance [24], although this may be due to    104 poor pedagogical planning by teachers or the unrestricted use of these tools by students 105 without proper guidance. Nevertheless, studies showing positive performance outcomes    106 outnumber those indicating negative results [25, 26]. 107
#
# Furthermore, research based on the application of the UTAUT model has highlighted    108 that factors such as hedonic motivation, performance expectancy, effort expectancy, and 109 social influence are key predictors of students' intention to use ChatGPT. In this regard,    110 [27] found that behavioral intention and facilitating conditions significantly influence the 111 actual use of this tool. Similar findings were reported by [28], who observed that usage    112 behavior  has  the  most  significant  impact  on  behavioral  intention,  followed  by  perfor113 mance  expectancy  and  hedonic  motivation.  Additionally,  behavioral  intention  signifi114 cantly influences actual usage, being modulated by habit and facilitating conditions. 115
#
# Finally, although students exhibit a high acceptance of AI in general and ChatGPT in    116 particular, they also acknowledge insufficient training for its effective use [20, 29]. In this 117 regard, various studies have pointed out that students demand greater training in this    118 field, emphasizing the need for structured and specific education on the use of AI in edu119 cational contexts [21]. These demands highlight the importance of designing educational    120 strategies that enable the effective pedagogical integration of AI, ensuring that students 121 acquire the necessary competencies for its critical and reflective use in academic settings. 122
#
# ## 3. Methods
#
# 123
#
# ## 3.1. Objectives
#
# 124
#
# The main objective of this study is to analyze the factors influencing the acceptance 125 and use of artificial intelligence by Latin American university students, specifically Costa    126 Rican students, based on the UTAUT2 model and using a partial least squares structural    127 equation modeling (PLS-SEM) approach. 128
#
# To achieve this purpose, the following specific objectives are established:
#
# 129
#
# - · Evaluate "Performance Expectancy" (PE) in the intention to use artificial intelligence in the university context, considering students' perceptions of the usefulness of tools like ChatGPT in their learning process.
#
# 130
#
# 131
#
# 132
#
# - · Analyze  "Effort  Expectancy"  (EE)  and  its  impact  on  AI  acceptance,  examining whether the simplicity of interaction with these technologies facilitates their adoption.
#
# 133
#
# 134
#
# 135
#
# - · Determine "Social Influence" (SI) in the intention to use AI, exploring the role that 136 academic and social opinions and recommendations play in students' willingness to    137 use artificial intelligence. 138
#
# - · Examine the effect of "Facilitating Conditions" (FC) on AI adoption, identifying the availability of resources, technological knowledge, and institutional support as key factors in the implementation of these tools.
#
# 139
#
# 140
#
# 141
#
# - · Measure "Behavioral Intention" (BI) and its relationship with "Usage Behavior" (UB)    142 in artificial intelligence, analyzing whether students' willingness to use these tools 143 translates into effective use in the educational field. 144
# - · Validate the structure of the UTAUT2 model in the context of higher education in    145 Latin America, assessing the robustness of the model through the analysis of factor    146 loadings, discriminant validity, and global fit using SRMR. 147
#
# ## 3.2. Research Sample
#
# 148
#
# The study sample consists of a total of 194 Costa Rican university students, distributed according to various sociodemographic and academic characteristics. Regarding gender, the majority of participants are women (n=124, 63.9%), while men account for 36.1% (n=70).
#
# 149
#
# 150
#
# 151
#
# 152
#
# In terms of age, the largest group corresponds to students aged 21 to 30 years (n=99, 51.0%), followed by those aged 18 to 20 years (n=57, 29.4%). Participants aged 31 to 40 years constitute 10.8% (n=21), while those aged 41 to 50 years and over 50 years represent 4.1% (n=8) and 4.6% (n=9), respectively.
#
# 153
#
# 154
#
# 155
#
# 156
#
# Regarding the field of study, there is a higher representation of students from Health    157 Sciences (n=73, 37.6%), followed by those from Social Sciences (n=39, 20.1%), Engineering 158 (n=32, 16.5%), and Economic Sciences (n=22, 11.3%). Students from Arts and Humanities 159 (n=15, 7.7%), Basic Sciences (n=11, 5.7%), and Agri-Food Sciences (n=2, 1.0%) have a sma160 ller representation in the sample. 161
#
# Finally, regarding the type of university, 54.1% (n=105) of the participants are from public universities, while 45.9% (n=89) are enrolled in private institutions.
#
# The research was conducted between November 2024 and January 2025.
#
# 162
#
# 163
#
# 164
#
# ## 3.3. Data Collection Instrument
#
# 165
#
# The  data  collection  instrument  used  in  this  study  was  designed  following  the    166 UTAUT2 model, adapted to assess the degree of acceptance of artificial intelligence in the 167 university setting, specifically regarding the use of ChatGPT. The questionnaire was de168 veloped based on the constructs of the model, ensuring the theoretical validity  of the    169 measurement and its applicability in the educational context. The questionnaire was ad170 ministered via an online platform (Google Forms), facilitating access to a larger number 171 of participants and ensuring efficient data collection. Before participating, students provi172 ded informed consent, ensuring compliance with the ethical principles of research. 173
#
# The questionnaire consists of 19 items distributed across different dimensions of the UTAUT2 model.
#
# 174
#
# 175
#
# - · The first dimension, "Academic Performance Expectancy" (PE), evaluates students'    176 perceptions of ChatGPT's usefulness in their academic performance. It includes four    177 items exploring the tool's impact on productivity, speed in completing tasks, and its 178 contribution to achieving academic goals. 179
# - · The second dimension, "Effort Expectancy" (EE), measures the perceived ease of use of ChatGPT, considering the clarity of interaction and the ease of learning the tool, with a total of four items.
#
# 180
#
# 181
#
# 182
#
# - · The third dimension, "Social Influence" (SI), consists of three items that investigate 183 the extent to which the opinions and recommendations of close individuals influence    184 students' adoption of ChatGPT. 185
#
# - · The  fourth  dimension,  "Facilitating  Conditions"  (FC),  gathers  information  on  the availability of resources and necessary knowledge for using artificial intelligence, as well as the compatibility of the tool with other technologies used by students. This dimension also includes one item regarding the possibility of receiving external support in case of difficulties with the tool.
#
# 186
#
# 187
#
# 188
#
# 189
#
# 190
#
# Finally, the "Behavioral Intention" (BI) and "Usage Behavior" (UB) dimensions assess    191 students' future willingness to continue using ChatGPT in their studies. The first consists 192 of three items measuring the intention to keep using the tool over time, while the second 193 collects information on the actual frequency of ChatGPT use in the academic context. 194
#
# Table 1 presents the different items that make up the instrument.
#
# 195
#
# Table 1. Items of the Measurement Instrument.
#
# | Item                                                                                          | Mean SD   | Mean SD   |
# |-----------------------------------------------------------------------------------------------|-----------|-----------|
# | PE1 I believe ChatGPT is useful in my studies                                                 | 6,11      | 1,346     |
# | PE2 Using ChatGPT increases your chances of achieving important things in  5,43  your studies |           | 1,650     |
# | PE3 Using ChatGPT helps you complete tasks and projects faster in your  studies               | 6,09      | 1,424     |
# | PE4 Using ChatGPT increases your productivity in your studies                                 | 5,61      | 1,613     |
# | EE1 Learning to use ChatGPT is easy for me                                                    | 6,17      | 1,376     |
# | EE2 My interaction with ChatGPT is clear and understandable                                   | 6,05      | 1,326     |
# | EE3 I find ChatGPT easy to use                                                                | 6,31      | 1,221     |
# | EE4 It is easy for me to acquire skills in using ChatGPT                                      | 5,97      | 1,454     |
# | SI1 The people who are important to me think that I should use ChatGPT                        | 4,49      | 1,990     |
# | SI2 The people who influence my behavior believe that I should use ChatGPT 4,26               |           | 2,065     |
# | SI3 The people whose opinions I value prefer that I use ChatGPT                               | 4,23      | 2,087     |
# | FC1 I have the necessary resources to use ChatGPT                                             | 6,54      | 1,068     |
# | FC2 I have the necessary knowledge to use ChatGPT                                             | 6,14      | 1,394     |
# | FC3 ChatGPT is compatible with the technologies I use                                         | 6,47      | 1,161     |
# | FC4 I can get help from others when I have difficulties using ChatGPT                         | 5,69      | 1,742     |
# | BI1 I intend to continue using ChatGPT in the future                                          | 6,06      | 1,491     |
# | BI2 I will always try to use ChatGPT in my studies                                            | 4,87      | 2,010     |
# | BI3 I plan to keep using ChatGPT frequently                                                   | 5,30      | 1,862     |
# | UB1 Choose your frequency of use for ChatGPT                                                  | 4,46      | 1,688     |
#
# Regarding the mean scores and standard deviations obtained in each of the dimensions, Table 2 presents a summary of the descriptive statistics for the UTAUT2 model dimensions:
#
# Table 2. Mean Scores and Standard Deviations.
#
# | Dimension                    | Mean   | SD    |
# |------------------------------|--------|-------|
# | Performance Expectancy (PE)  | 5,81   | 1,303 |
# | Effort Expectancy (EE)       | 6,13   | 1,160 |
# | Social Influence (SI)        | 4,33   | 1,933 |
# | Facilitating Conditions (FC) | 6,21   | 1,059 |
# | Behavioral Intention (BI)    | 5,41   | 1,651 |
# | Usage Behavior (UB)          | 4,46   | 1,688 |
#
# 196
#
# 197
#
# 198
#
# 199
#
# 200
#
# 201
#
# For data analysis, structural equation modeling (SEM) was employed using partial    204 least squares (PLS-SEM) with SmartPLS software. This approach was selected due to its    205 ability to model complex relationships between latent and observed variables, allowing    206 for the simultaneous assessment of the validity of the UTAUT2-based theoretical model    207 and the influence of its constructs on university students' acceptance of artificial intelli208 gence. 209
#
# First, the validity and reliability of the measurement model were assessed through    210 factor loadings analysis, considering a minimum threshold of 0.70 for item acceptance. 211 Additionally, the internal  consistency  of each construct was verified  using Cronbach's 212 alpha and composite reliability (CR), with an acceptance criterion set above 0.70. Conver213 gent  validity  was  confirmed  using  average  variance  extracted  (AVE),  ensuring  values 214 above 0.50. 215
#
# To ensure discriminant validity, the Fornell-Larcker criterion was applied, comparing the square root of AVE with the correlations between constructs. After validating the measurement model, the structural model analysis was conducted, evaluating the significance and magnitude of path coefficients using the bootstrapping procedure with 5,000 resamples. Determination coefficients (R² ) were calculated to estimate the explained variance of endogenous variables, and f²  values were used to assess the effect size of each predictor.
#
# Additionally, the Standardized Root Mean Square Residual (SRMR) was incorporated as a global model fit indicator. An SRMR value below 0.08 was considered a good fit criterion, allowing for an evaluation of the discrepancy between the observed and estimated covariance matrices.
#
# 216
#
# 217
#
# 218
#
# 219
#
# 220
#
# 221
#
# 222
#
# 223
#
# 224
#
# 225
#
# 226
#
# ## 4. Results
#
# 227
#
# To  begin  with,  in  order  to  validate  the  factorial  structure  of  the  model,  a  factor 228 loadings analysis of the items was conducted, ensuring that all loadings were close to 0.7,    229 [30] which guarantees adequate convergent validity (Table 3). 230
#
# 231
#
# |     | BI    | EE    | FC    | PE    | SI    | UB    |
# |-----|-------|-------|-------|-------|-------|-------|
# | BI1 | 0.858 |       |       |       |       |       |
# | BI2 | 0.939 |       |       |       |       |       |
# | BI3 | 0.954 |       |       |       |       |       |
# | EE1 |       | 0.847 |       |       |       |       |
# | EE2 |       | 0.885 |       |       |       |       |
# | EE3 |       | 0.868 |       |       |       |       |
# | EE4 |       | 0.835 |       |       |       |       |
# | FC1 |       |       | 0.879 |       |       |       |
# | FC2 |       |       | 0.893 |       |       |       |
# | FC3 |       |       | 0.650 |       |       |       |
# | FC4 |       |       | 0.693 |       |       |       |
# | PE1 |       |       |       | 0.895 |       |       |
# | PE2 |       |       |       | 0.857 |       |       |
# | PE3 |       |       |       | 0.825 |       |       |
# | PE4 |       |       |       | 0.839 |       |       |
# | SI1 |       |       |       |       | 0.904 |       |
# | SI2 |       |       |       |       | 0.964 |       |
# | SI3 |       |       |       |       | 0.941 |       |
# | UB  |       |       |       |       |       | 1.000 |
#
# The results confirm adequate convergent validity of the measurement model, as most    233 items exhibit factor loadings above 0.7, indicating that each item significantly contributes    234 to its respective construct. 235
#
# For behavioral intention (BI), factor loadings range between 0.858 and 0.954, reflecting a strong correlation between the items and the construct. Perceived ease of use (EE) also shows high values, with loadings between 0.835 and 0.885.
#
# 236
#
# 237
#
# 238
#
# Regarding facilitating conditions (FC), three of its items show adequate values (FC1 and FC2 above 0.87), although FC3 (0.650) and FC4 (0.693) exhibit slightly lower loadings, which might suggest a weaker contribution of these items to the construct.
#
# 239
#
# 240
#
# 241
#
# Performance expectancy (PE) presents factor loadings ranging from 0.825 to 0.895,    242 while social influence (SI) displays particularly high values, with loadings above 0.90 for 243 all its items. 244
#
# Finally, actual use (UB) has a value of 1.000, indicating that it is measured with a single item.
#
# The  internal  consistency  of  the  constructs  was  also  confirmed  using  Cronbach's alpha, composite reliability (CR), and average variance extracted (AVE).
#
# The values are presented in Table 4.
#
# Table 4. Internal Consistency.
#
# |    | Cronbach's  Composite re- Average variance   | Cronbach's  Composite re- Average variance   | Cronbach's  Composite re- Average variance   |
# |----|----------------------------------------------|----------------------------------------------|----------------------------------------------|
# |    | alpha                                        | liability                                    | extracted (AVE)                              |
# | BI | 0.906                                        | 0.908                                        | 0.843                                        |
# | EE | 0.882                                        | 0.889                                        | 0.738                                        |
# | FC | 0.800                                        | 0.923                                        | 0.618                                        |
# | PE | 0.877                                        | 0.884                                        | 0.730                                        |
# | SI | 0.930                                        | 0.936                                        | 0.877                                        |
#
# 251
#
# The results confirm the adequate internal consistency of the model's constructs [31].    252 First, all Cronbach's alpha values exceed the recommended threshold of 0.7, indicating 253 high internal reliability  of  the  items  within  each  construct.  In  particular,  the  social  in254 fluence (SI) construct shows the highest value (0.930), followed by behavioral intention 255 (BI) with 0.906, reflecting strong coherence among its items. 256
#
# The composite reliability (CR) also reaches satisfactory values in all cases, exceeding the 0.7 threshold and approaching or surpassing 0.9 in several constructs, reinforcing the robustness of the model.
#
# 257
#
# 258
#
# 259
#
# Finally, the AVE (average variance extracted), which measures the amount of va260 riance explained by the items relative to the error, presents values above the minimum    261 criterion of 0.5, except for  facilitating conditions (FC), which shows a value of 0.618 -262 slightly lower than the others but still within acceptable ranges. 263
#
# Subsequently, discriminant validity was assessed using the Fornell-Larcker criterion    264 (Table 5). According to this criterion, a construct should share more variance with its own 265 indicators than with other constructs in the model. This is confirmed when the square root    266 of the AVE for each construct (values on the diagonal) is greater than the correlations 267 between constructs (values outside the diagonal). 268
#
# 269
#
# |    |    BI | EE    | FC    | PE   | SI   | UB   |
# |----|-------|-------|-------|------|------|------|
# | BI | 0.918 |       |       |      |      |      |
# | EE | 0.58  | 0.859 |       |      |      |      |
# | FC | 0.511 | 0.662 | 0.786 |      |      |      |
#
# 245
#
# 246
#
# 247
#
# 248
#
# 249
#
# 250
#
# | PE   |   0.757 |   0.550 |   0.543 |   0.854 |       |       |
# |------|---------|---------|---------|---------|-------|-------|
# | SI   |   0.483 |   0.381 |   0.283 |   0.584 | 0.937 |       |
# | UB   |   0.613 |   0.498 |   0.432 |   0.534 | 0.359 | 1.000 |
#
# Subsequently, discriminant validity was assessed using the Fornell-Larcker criterion    270 (Table 5). According to this criterion, a construct should share more variance with its own indicators than with other constructs in the model. This is confirmed when the square root    272 of the AVE for each construct (values on the diagonal) is greater than the correlations between constructs (values outside the diagonal).
#
# In this case, all diagonal values exceed the correlations with other constructs, indicating adequate discriminant validity. In particular, behavioral intention (BI) presents a diagonal value of 0.918, which is higher than its correlations with the other variables, with the highest correlation being with performance expectancy (PE) (0.757).
#
# Similarly, effort expectancy (EE) has a square root of AVE of 0.859, with moderate correlations with the other variables, particularly its relationship with facilitating conditions (FC) (0.662). Likewise, the social influence (SI) construct exhibits the highest level of independence (0.937), with relatively low correlations with the other dimensions.
#
# Once the measurement model was validated, the relationships between constructs    283 were analyzed using structural equation modeling (PLS-SEM) (Figure 1).
#
# <!-- image -->
#
# 286
#
# 287
#
# The most relevant result is the strong influence of performance expectancy (PE) on    288 behavioral intention (BI), with a coefficient of 0.596, suggesting that students perceive the 289 usefulness of AI as a key factor in its adoption. Similarly, behavioral intention (BI) has a 290 significant impact on actual use (UB), with a coefficient of 0.530, confirming that intention 291 is a direct predictor of usage behavior. 292
#
# Effort expectancy (EE) also shows a positive relationship with behavioral intention 293 (BI) (0.214), although to a lesser extent than performance expectancy. On the other hand, 294 social influence (SI) and facilitating conditions (FC) have a much lower impact on beha295 vioral intention (0.044 and 0.034, respectively), suggesting that these factors are not pri296 mary determinants in students' intention to adopt AI. However, facilitating conditions    297 (FC) exhibit a more relevant effect on actual use (UB) (0.161), indicating that access to 298
#
# resources and technical support may influence the effective adoption of AI in the academic environment.
#
# 299
#
# 300
#
# Additionally, the model explains 64.4% of the variance in behavioral intention (BI) 301 and 39.5% of the variance in actual use (UB), indicating a moderate-to-high explanatory    302 power in predicting AI adoption in the university context. 303
#
# To evaluate the statistical significance of the path coefficients, the bootstrapping method with 5,000 resamples was applied (Table 6).
#
# Table 6. Path Coefficients.
#
# |          |   Original  sample (O)    mean (M) |   Sample |   Standard  deviation  (STDEV) |   T statistics  (|O/STDEV |) |   P values |
# |----------|------------------------------------|----------|--------------------------------|------------------------------|------------|
# | BI -&gt; UB |                              0.53  |    0.527 |                          0.092 |                        5.746 |      0     |
# | EE -&gt; BI |                              0.214 |    0.219 |                          0.103 |                        2.079 |      0.001 |
# | FC -&gt; BI |                              0.034 |    0.038 |                          0.088 |                        0.384 |      0.001 |
# | FC -&gt; UB |                              0.161 |    0.165 |                          0.079 |                        2.041 |      0.031 |
# | PE -&gt; BI |                              0.596 |    0.591 |                          0.099 |                        5.999 |      0     |
# | SI -&gt; BI |                              0.044 |    0.046 |                          0.093 |                        0.469 |      0.023 |
#
# 307
#
# The results confirm that most path coefficients are statistically significant, as their p308 values are below 0.05. In particular, the strong influence of performance expectancy (PE) 309 on behavioral intention (BI) stands out, with a coefficient of 0.596 and a t-value of 5.999,    310 indicating a robust and highly significant relationship (p = 0.000). Similarly, behavioral 311 intention (BI) has a considerable impact on actual use (UB), with a coefficient of 0.530 and 312 a t-value of 5.746, reaffirming its role as a key predictor of adoption behavior. 313
#
# Effort expectancy (EE) also shows a significant relationship with behavioral intention (BI) (β = 0.214, t = 2.079, p = 0.001), although its impact is lower than performance expectancy. On the other hand, facilitating conditions (FC) have a significant effect on actual use (UB) (β = 0.161, t = 2.041, p = 0.031), suggesting that access to resources and support influences the effective use of AI. However, its impact on behavioral intention (BI) is very low and not significant (β = 0.034, t = 0.384, p = 0.001).
#
# 314
#
# 315
#
# 316
#
# 317
#
# 318
#
# 319
#
# Social influence (SI), with a coefficient of 0.044 and a t-value of 0.469, shows a weak    320 relationship with behavioral intention, although it remains statistically significant (p = 321 0.023). This suggests that peer perception has a minor impact on students' adoption of AI. 322
#
# Finally, to evaluate the overall model fit, the Standardized Root Mean Square Resi323 dual (SRMR) was analyzed, yielding a value of 0.062. This result indicates a good model 324 fit, as it falls below the recommended threshold of 0.08 in the PLS-SEM literature. A low    325 SRMR value suggests minimal discrepancy between the observed and estimated cova326 riance matrices, supporting the adequacy of the proposed model [31]. These findings rein327 force the validity of the UTAUT2 model in predicting students' acceptance of ChatGPT. 328
#
# After conducting these analyses, we proceeded to examine the influence of other variables, such as gender, age, and field of study, on the degree of ChatGPT acceptance.
#
# For all cases, the hypotheses were formulated as follows:
#
# - · Null Hypothesis (H₀): There are no significant differences based on gender, with an alpha risk of 0.05 for the different variables tested.
# - · Alternative Hypothesis (H₁): There are significant differences based on gender, with an alpha risk of 0.05 for the different variables tested.
#
# Starting with the gender variable, and applying the Mann-Whitney U test, we obtained the results presented in Table 7.
#
# 329
#
# 330
#
# 331
#
# 332
#
# 333
#
# 334
#
# 335
#
# 336
#
# 337
#
# 304
#
# 305
#
# 306
#
# Table 7. Significant Differences Based on Students' Gender Across the Different UTAUT Dimensions
#
# |                  | PE      | EE      | SI      | FC      | BI      | UB      |
# |------------------|---------|---------|---------|---------|---------|---------|
# | Mann-Whit- ney U | 3982,5  | 4078,0  | 3653,0  | 3977,5  | 3612,0  | 3490,0  |
# | Wilcoxon W       | 11732,5 | 11828,0 | 11403,0 | 11727,5 | 11362,0 | 11240,0 |
# | Z                | -,972   | -,721   | -1,838  | -,997   | -1,976  | -2,326  |
# | Sig.             | ,331    | ,471    | ,066    | ,319    | ,048(*) | ,020(*) |
#
# Note: * = significant differences at the 0.05 level.
#
# The results obtained only allow for the rejection of H₀ at a significance level of p ≤ 0.05 concerning "behavioral intention" and "usage behavior".
#
# To determine which gender these differences favored, a rank test was applied, yielding the values presented in Table 8 for the two accepted alternative hypotheses.
#
# Table 8. Rank Test Between "Behavioral Intention" and "Usage Behavior" Dimensions and Students' Gender.
#
# | Dimension    | Gender   |   N | Mean Rank   | Sum of  Ranks   |
# |--------------|----------|-----|-------------|-----------------|
# | BI (Behav-   | Male     |  70 | 107,90      | 7553,00         |
# | ioral Inten- | Female   | 124 | 91,63       | 11362,00        |
# | tion)        | Total    | 194 |             |                 |
# | UB (Usage    | Male     |  70 | 109,64      | 7675,00         |
# | Behavior)    | Female   | 124 | 90,65       | 11240,00        |
#
# Regarding age, the Kruskal-Wallis test was applied, and the results obtained are presented in Table 9.
#
# Table 9. Significant Differences Based on Students' Age Across the Different UTAUT Dimensions.
#
# |          | PE    | EE      | SI    | FC    | BI      | UB      |
# |----------|-------|---------|-------|-------|---------|---------|
# | Kruskal- | 1,826 | 11,092  | 7,760 | 6,437 | 9,552   | 11,126  |
# | Wallis H |       |         |       |       |         |         |
# | df       | 4     | 4       | 4     | 4     | 4       | 4       |
# | Sig.     | ,768  | ,026(*) | ,101  | ,169  | ,049(*) | ,025(*) |
# | Kruskal- | PE    | EE      | SI    | FC    | BI      | UB      |
# | Wallis H |       |         |       |       |         |         |
#
# Note: * = significant differences at the 0.05 level.
#
# In this case, the H₀ hypotheses rejected at p ≤ 0.05  were those related to the nonexistence  of  significant  differences  concerning  age  and  the  following  UTAUT2  dimensions: "Usage Behavior," "Behavioral Intention," and "Effort Expectancy."
#
# In Table 10, the differences in the rejected hypothesis are presented, indicating which age group the differences favored. To determine this, the rank test was applied again.
#
# Table 10. Rank Test Between "Usage Behavior," "Behavioral Intention," and "Effort Expectancy" Dimensions and Students' Age
#
# |                        | Age Group   |   N Mean Rank | N Mean Rank   |
# |------------------------|-------------|---------------|---------------|
# | EE (Effort Expectancy) | 18-20 years |            57 | 96,65         |
# |                        | 21-30 years |            99 | 106,37        |
# |                        | 31-40 years |            21 | 63,62         |
# |                        | 41-50 years |             8 | 90,94         |
#
# 340
#
# 341
#
# 342
#
# 343
#
# 344
#
# 345
#
# 346
#
# 347
#
# 348
#
# 349
#
# 350
#
# 351
#
# 352
#
# 353
#
# 354
#
# 355
#
# 356
#
# 357
#
# 358
#
# | UB (Usage Behavior)   | Over 50 years  9                       |     | 90,22   |
# |-----------------------|----------------------------------------|-----|---------|
# | UB (Usage Behavior)   | Total                                  | 194 |         |
# | UB (Usage Behavior)   | BI (Behavioral Intention)  18-20 years | 57  | 84,88   |
# | UB (Usage Behavior)   | 21-30 years                            | 99  | 104,93  |
# | UB (Usage Behavior)   | 31-40 years                            | 21  | 79,74   |
# | UB (Usage Behavior)   | 41-50 years                            | 8   | 114,06  |
# | UB (Usage Behavior)   | Over 50 years  9                       |     | 122,44  |
# | UB (Usage Behavior)   | Total                                  | 194 |         |
# | UB (Usage Behavior)   | 18-20 years                            | 57  | 91,21   |
# | UB (Usage Behavior)   | 21-30 years                            | 99  | 107,09  |
# | UB (Usage Behavior)   | 31-40 years                            | 21  | 76,26   |
# | UB (Usage Behavior)   | 41-50 years                            | 8   | 61,81   |
# | UB (Usage Behavior)   | Over 50 years  9                       |     | 113,11  |
# | UB (Usage Behavior)   | Total                                  | 194 |         |
#
# The results indicate that, in general, students aged 21-30 years exhibited the highest    360 acceptance of the technology analyzed in this study.
#
# Finally, we tested H₀, referring to the existence or absence of significant differences across the various UTAUT2 dimensions based on the students' field of study. The KruskalWallis values presented in Table 11 indicate that none of the H₀ hypotheses can be rejected at p ≤ 0.05. Consequently, we can conclude that there are no significant differences between the various UTAUT dimensions regarding the acceptance of ChatGPT and the    366 students' field of study.
#
# Table 11. Kruskal-Wallis Test Results for Field of Study.
#
# |          | PE     | EE     | SI     | FC     | BI    |
# |----------|--------|--------|--------|--------|-------|
# | Kruskal- | 11,995 | 10,285 | 12,486 | 10,609 | 7,385 |
# | Wallis H |        |        |        |        |       |
# | df       | 6      | 6      | 6      | 6      | 6     |
# | Sig.     | ,062   | ,113   | ,052   | ,101   | ,287  |
#
# ## 5. Conclusions, Research Limitations, and Future Research Directions
#
# 369
#
# This study has systematically addressed the degree of acceptance of ChatGPT among    370 Costa Rican university students, using the UTAUT2 (Unified Theory of Acceptance and    371 Use of Technology) model as a theoretical framework. The findings point in different di372 rections: 373
#
# The first key aspect relates to the validity and reliability of the instrument used to analyze students' acceptance of ChatGPT.
#
# 374
#
# 375
#
# Additionally, the model has been validated, indicating that dimensions such as Per376 formance Expectancy, Effort Expectancy, Social Influence, Facilitating Conditions, and Be377 havioral Intention are key factors in determining students' usage behavior of this AI-based    378 tool. In particular, it has been observed that students who use ChatGPT more frequently    379 tend to perceive it as a useful and easy-to-use tool, highlighting the need for its effective 380 integration into educational environments. 381
#
# The findings of this study align with previous research conducted by [32, 33, 34, 35,    382 28, 36, 37], suggesting that the UTAUT2 model is well-established as a robust theoretical    383 framework for understanding technological acceptance in the educational field. These re384 sults reinforce the importance of continuing to explore the factors that influence students' 385 willingness to adopt AI technologies in their learning processes. 386
#
# The incorporation of AI-based tools, such as ChatGPT, in higher education presents    387 a set of challenges for both teachers and students. Both groups must adapt to a dynamic    388
#
# teaching-learning ecosystem, which requires continuous updates in their knowledge and    389 digital skills. Digital literacy thus becomes a fundamental component in ensuring an ef390 fective adaptation to these new scenarios. In this context, [16] found that a significant pro391 portion of students use AI tools at least once a week, suggesting a positive inclination 392 toward their integration into academic practices. 393
#
# Additionally, this study has highlighted that the degree of acceptance of ChatGPT is 394 influenced by students' gender and age. Men show greater interest in this technology, and    395 the age group of 21-30 years exhibits the highest level of acceptance. 396
#
# This study provides a valuable contribution from both a scientific and social perspec397 tive, offering a deeper understanding of AI acceptance in education. Its findings can serve 398 as a foundation for future research aimed at examining in greater detail the interaction 399 between technology and learning. Additionally, it provides useful insights for educational 400 institutions and academic policymakers, facilitating evidence-based decision-making re401 garding the implementation of training programs and the development of technological    402 resources. 403
#
# Despite its contributions, this study has some limitations that should be considered for a comprehensive understanding of the results:
#
# 404
#
# 405
#
# - · Sampling Method: The study employed a convenience sampling method, which pre406 sents  certain  disadvantages  compared  to  random  sampling  [38].  Future  research    407 should replicate this study using a random selection of participants. 408
# - · Self-Reported Data: The data collection instrument relied on self-reports, which have    409 inherent limitations [39]. However, as Yousafzai, Foxall &amp;amp; Pallister [40] point out,    410 obtaining  objective  measures  of  technology  acceptance  is  challenging,  unless  the 411 technology is used consistently. 412
# - · Ex-Post-Facto Design: The ex-post-facto methodological design prevents the establishment of causal relationships between the analyzed variables. Future Research Directions
#
# 413
#
# 414
#
# 415
#
# Training in AI-based tools is a key factor in the technology adoption process. This is 416 not only because AI is transforming teaching and learning methods, but also due to its    417 broader social and cultural implications. Chang et al. [41] emphasize that students' ability    418 to use ChatGPT significantly influences their acceptance of the tool, reinforcing the need 419 to provide appropriate training programs to enhance its pedagogical use. In this sense,    420 the AI revolution extends beyond technology, becoming a phenomenon that redefines in421 teractions with knowledge and education. 422
#
# Ultimately, the real challenge is not just learning to use these tools, as this process 423 will naturally occur over time. The crucial aspect is to understand and manage the struc424 tural changes that AI will introduce in society and education, as well as the ideological 425 values underlying its implementation [42]. This perspective invites a critical reflection on    426 AI's impact, not only in the academic field but also within the sociocultural framework in 427 which it operates. 428
#
# Therefore, future research should expand the scope of this study to other fields of    429 knowledge and educational levels, aiming to achieve a more holistic understanding of    430 ChatGPT acceptance. Additionally, it would be pertinent to analyze the long-term impact    431 of AI use on academic performance and the development of students' digital competen432 cies. 433
#
# A  mixed-method  approach,  combining  qualitative  and  quantitative  techniques,    434 would allow for a deeper understanding of students' perceptions and attitudes toward AI 435 in education. Moreover, as suggested by Tamilmani, Rana, Wamba &amp; Dwivedi [33] in their    436 meta-analysis on UTAUT2 and AI research, it is crucial to consider contextual variables    437
#
# | to better understand technology adoption levels, which would necessitate replicating this                  |   438 |
# |------------------------------------------------------------------------------------------------------------|-------|
# | study.                                                                                                     |   439 |
# | 6. Patents                                                                                                 |   440 |
# | Author  Contributions:   Conceptualization,  J.C.-A.  and  A.P.-R.;  methodology,  A.P.-R.;  software,     |   441 |
# | H.d.l.A.R.G.;  validation,  J.C.-A.,  A.P.-R.,  and  V.F.-S.;  formal  analysis,  A.P.-R.;  investigation, |   442 |
# | H.d.l.A.R.G.; resources, J.C.-A.; data curation, V.F.-S.; writing - original draft preparation, A.P.-R.;   |   443 |
# ...
# | 20.   | Almaraz-López, C.; Almaraz-Menéndez, F.; López-Esteban, C. Comparative study of the attitudes and perceptions of university  students in business administration and management and in education toward artificial intelligence.  Education Sciences ,  2023 ,                                                                                                  |           |
# |       |                                                                                                                                                                                                                                                                                                                                                                 | 492       |
# |       | (6).                                                                                                                                                                                                                                                                                                                                                            | 493       |
# |       | 13 Palomino, S.; Vázquez, J.C. Percepción de los universitarios ante la formación y uso de herramientas de IA.  Instituto                                                                                                                                                                                                                                       | 494       |
# | 21.   | para el Futuro de la Educació n ,  2023 .                                                                                                                                                                                                                                                                                                                       | 495 496   |
# | 22.   | Laí nez, G.; Tumbaco, M.; Ricardo, J.; Peñafiel, R.; Zambrano, W.; Del Pezo, A. Perception of university students on the use of                                                                                                                                                                                                                                 | 497       |
# |       | artificial intelligence (AI) tools for the development of autonomous learning.  Revista de Gestã o Social e Ambiental ,  2024 ,  18 (2).                                                                                                                                                                                                                        | 498       |
# | 23.   | Ortega-Rodrí guez, P.J.; Pericacho-Gómez, F.J. La utilidad didáctica percibida del ChatGPT por parte del alumnado universitario                                                                                                                                                                                                                                 | 499       |
# |       | [The educational perceived usefulness of ChatGPT by university students].  Pixel-Bit. Revista de Medios y Educació n ,  2025 ,  72 , 159 -                                                                                                                                                                                                                      | 500       |
# |       | 178.                                                                                                                                                                                                                                                                                                                                                            | 501       |
# | 24.   | Castro-López, A.; Cervero, A.; Á lvarez-Blanco, L. Análisis sobre el uso de las herramientas de inteligencia artificial interactiva                                                                                                                                                                                                                             | 502       |
# |       | en el entorno universitario.  Revista Tecnologí, Ciencia y Educació n a ,  2025 ,  30 , 37 - 66.                                                                                                                                                                                                                                                                | 503       |
# | 25.   | Loayza-Maturrano, E. Percepción de estudiantes de una universidad de Lima sobre el uso de ChatGPT en la escritura acadé-                                                                                                                                                                                                                                        | 504       |
# |       | mica.  Educare et Comunicare ,  2024 ,  12 (2), 28-38.                                                                                                                                                                                                                                                                                                          | 505       |
# | 26.   | Tlili, A. Can artificial intelligence (AI) help in computer science education? A meta-analysis approach [¿Puede ayudar la inteli-                                                                                                                                                                                                                               | 506       |
# |       | gencia artificial (IA) en la educación en ciencias de la computación? Un enfoque metaanalí tico].  Revista Españ ola de Pedagogí a ,  2024 ,  82 (289).                                                                                                                                                                                                         | 507 508   |
# | 27.   | Arthur, F.; Salifu, I.; Abam Nortey, S. Predictors of higher education students' behavioural intention and usage of ChatGPT:  the                                                                                                                                                                                                                               |           |
# |       | moderating roles of age, gender and experience.  Interactive Learning Environments ,  2024 ,  1 - 27 .                                                                                                                                                                                                                                                          | 509       |
# | 28.   | Strzelecki, A. To use or not to use ChatGPT in higher education? A study of students' acceptance and use of technology.  Inter-                                                                                                                                                                                                                                 | 510 511   |
# |       | active Learning Environments ,  2023 .                                                                                                                                                                                                                                                                                                                          | 512       |
# | 29.   | Solano-Barliza,  A.;  Ojeda,  A.;  Aaron-Gonzalvez,  M.  Análisis  cuantitativo  de  la  percepción  del  uso  de  inteligencia  artificial                                                                                                                                                                                                                     |           |
# |       | ChatGPT en la enseñanza y aprendizaje de estudiantes de pregrado del Caribe colombiano.  Formació n Universitaria ,  2024 ,  17 (3),                                                                                                                                                                                                                            | 513 514   |
# | 30.   | 129-138.  Carmines, E. G.; Zeller, R. A.  Reliability and Validity Assessment , Vol. 17; Thousand Oaks, CA: Sage, 1979.                                                                                                                                                                                                                                         | 515 516   |
# | 31.   | Bagozzi, R.P.; Yi, Y. On the evaluation of structural equation models.  Journal of the Academy of Marketing Science ,  1988 ,  16 , 74-94.                                                                                                                                                                                                                      | 517       |
# | 32.   | Gansser, O.; Reich, Ch. A new acceptance model for artificial intelligence with extensions to UTAUT2: An empirical study in                                                                                                                                                                                                                                     | 518       |
# |       | three segments of application.  Technology in Society ,  2021 ,  65 .                                                                                                                                                                                                                                                                                           | 519       |
# | 33.   | Tamilmani,  K.;  Rana,  N.;  Wamba,  F.;  Dwivedi,  R.  The  extended  Unified  Theory  of  Acceptance  and  Use  of  Technology                                                                                                                                                                                                                                | 520       |
# |       | (UTAUT2): A systematic literature review and theory evaluation.  International Journal of Information Management ,  2021 ,  57 .                                                                                                                                                                                                                                | 521       |
# | 34.   | Schmitz, A.; Dí az-Martí n, A.; Yagüe, M.J. Modifying UTAUT2 for a cross-country comparison of telemedicine adoption.  Com- puters in Human Behavior ,  2022 ,  130 .                                                                                                                                                                                           | 522 523   |
# | 35.   |                                                                                                                                                                                                                                                                                                                                                                 | 524       |
# |       | Cao, Y.; Abdul, A.L.; Mohd, W. University students' perspectives on Artificial Intelligence: A survey of attitudes and awaren ess  among Interior Architecture students.  International Journal of Educational Research and Innovation (IJERI) ,  2023 ,  20 , 1-21.                                                                                            | 525       |
# | 36.   | Strzelecki, A.; ElArabawy, S. Investigation of the moderation effect of gender and study level on the acceptance and use of  generative AI by higher education students: Comparative evidence from Poland and Egypt.  British Journal of Educational Tech-                                                                                                      | 526       |
# |       |                                                                                                                                                                                                                                                                                                                                                                 | 527       |
# | 37.   | nology ,  2024 ,  55 , 1209 - 1230.                                                                                                                                                                                                                                                                                                                             | 528       |
# |       | Saif, N.; Khan, S. U.; Shaheen, I.; Alotaibi, A.; Alnfiai, M. M.; Arif, M. Chat-GPT; validating Technology Acceptance Model                                                                                                                                                                                                                                     | 529       |
# |       | (TAM) in education sector via ubiquitous learning mechanism.  Computers in Human Behavior ,  2024 ,  154 .                                                                                                                                                                                                                                                      |           |
# | 38.   | Otzen, T.; Manterola, C. Técnicas de muestreo sobre una población a estudio.  International Journal of Morphology ,  2017 ,  35 (1),                                                                                                                                                                                                                            | 530       |
# |       | 227-232.                                                                                                                                                                                                                                                                                                                                                        | 531 532   |
#
# | 39.   | Del Valle, M.; Zamora, E. El uso de las medidas de auto-informe: ventajas y limitaciones en la investigación en Psicologí a.         |   533 |
# |-------|--------------------------------------------------------------------------------------------------------------------------------------|-------|
# |       | Alternativas Psicoló gicas ,  2022 ,  47 , 22-35.                                                                                    |   534 |
# | 40.   | Yousafzai, S. Y.; Foxall, G. R.; Pallister, J. G. Technology acceptance: A meta-analysis of the TAM: Part 1.  Journal of Modeling in |   535 |
# |       | Management ,  2007 ,  2 (3), 251-280.                                                                                                |   536 |
# | 41.   | Chang, H.; Liu, B.; Zhao, Y.; Li, Y.; He, F. Research on the acceptance of ChatGPT among different college student groups based      |   537 |
# |       | on latent class analysis.  Interactive Learning Environments ,  2024 ,  1 - 17 .                                                     |   538 |
# | 42.   | Cortina, A.  ¿ É tica o ideologí de la inteligencia artificial? a  Paidós,  2024 .                                                   |   539 |
# |       | Disclaimer/Publisher's Note:  The statements, opinions and data contained in all publications are solely those of the individual au- |   540 |
# |       | thor(s) and contributor(s) and not of MDPI and/or the editor(s). MDPI and/or the editor(s) disclaim responsibility for any injury to |   541 |
# |       | people or property resulting from any ideas, methods, instructions or products referred to in the content.                           |   542 |
