# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'svg'

# Load data from URL into DataFrame
url = "https://raw.githubusercontent.com/radiukpavlo/my-operations-research/main/data/df_results.csv"
df_results = pd.read_csv(url)

# Get unique emotions
emotions = df_results['Emotion'].unique()

# Loop over each emotion
for emotion in emotions:
    # Filter rows for the current emotion
    emotion_data = df_results[df_results['Emotion'] == emotion]

    # Melt the DataFrame to long format for easy plotting with seaborn
    emotion_data_melt = pd.melt(emotion_data, id_vars=['Matrix', 'Emotion'], value_vars=['Precision', 'Recall', 'F1-Score', 'Accuracy'])

    # Plot the data
    plt.figure(figsize=(10,6))
    barplot = sns.barplot(x='Matrix', y='value', hue='variable', data=emotion_data_melt)

    # Add title and labels
    plt.title('Metrics for {} Emotion'.format(emotion))
    plt.ylabel('Value')
    plt.xlabel('Matrix')

    # Move the legend to an empty part of the plot
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

    # Add data values on top of each bar
    for p in barplot.patches:
        barplot.annotate(format(p.get_height(), '.2f'), 
                        (p.get_x() + p.get_width() / 2., p.get_height()), 
                        ha = 'center', va = 'center', 
                        xytext = (0, 10), 
                        textcoords = 'offset points')
    #save the plot
    plt.savefig(f'figures/{emotion}_{metric}.svg', format='svg', bbox_inches='tight')
    
    # Show the plot
    plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Download the data frame
url = 'https://raw.githubusercontent.com/radiukpavlo/my-operations-research/main/data/df_results.csv'
df_results = pd.read_csv(url)

# Define the emotions and metrics
emotions = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
metrics = ['Precision', 'Recall', 'F1-Score', 'Accuracy']

# Plot histograms for each emotion and metric
for emotion in emotions:
    for metric in metrics:
        plt.figure(figsize=(8, 6))
        sns.barplot(x='Matrix', y=metric, data=df_results[df_results['Emotion'] == emotion], palette='Set2')
        plt.xlabel('Matrix')
        plt.ylabel(metric)
        plt.title(f'{emotion.capitalize()} - {metric}')
        plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
        plt.savefig(f'{emotion}_{metric}.svg', format='svg', bbox_inches='tight')
        plt.close()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...
