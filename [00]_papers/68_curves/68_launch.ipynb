# %%
# %run generate_scalability_plot.py
# Out:
# Saved PDF plot to 68_fig_a6.pdf

# %%
# %run generate_heatmap.py
# Out:
# Heatmap: evaluated 66 simplex points with step 0.1.
#   HDBSCAN-first: 40 combinations
#   k-means-first: 3 combinations
#   Hybrid: 23 combinations
#   Hybrid threshold triggered for 23 combinations (|delta| <= 0.03).
#   Smallest decisive gap outside tolerance: 0.0310.
# Reference weights (1/3, 1/3, 1/3) produce HDBSCAN-first with |delta|=0.0400.
# Saved heatmap PNG to D:\GitHub\my-study-python\[00]_papers\68_curves\68_fig_a1.png
# Saved vector PDF to D:\GitHub\my-study-python\[00]_papers\68_curves\68_fig_a1.pdf
