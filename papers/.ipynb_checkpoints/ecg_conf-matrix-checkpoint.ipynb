# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Підвищимо розмір графіків за замовчуванням
plt.style.use('ggplot')
# plt.rcParams['figure.figsize'] = 7, 5
# plt.rcParams['axes.grid'] = True

# %%
array_7a = [[26405, 97, 11, 16, 42, 9, 2],
            [59, 1169, 10, 7, 19, 2, 3],
            [81, 2, 2746, 2, 30, 2, 1],
            [48, 16, 24, 1813, 0, 3, 0],
            [175, 29, 11, 1, 628, 0, 2],
            [5, 2, 0, 0, 0, 4, 0],
            [4, 3, 1, 1, 0, 0, 31]]

# df_cm = pd.DataFrame(array, index = [i for i in "NVRLA!E"],
#                   columns = [i for i in "NVRLA!E"])

# fig, ax = plt.subplots(figsize=(6,6), dpi=600)

plt.figure(figsize=(6, 6), dpi = 600)

sns.heatmap(array_7a, cmap='Blues', annot=True, xticklabels='NVRLA!E',
            yticklabels='NVRLA!E', annot_kws={"size": 10, "weight": "bold"},
            fmt='3g', square=True, linewidths=0.5, cbar_kws={"shrink": 1})

#plt.tick_params(axis='x', labelsize=12) # x font label size
#plt.tick_params(axis='y', labelsize=12) # y font label size

plt.yticks(fontweight='bold', fontsize=10, rotation=0)
plt.xticks(fontweight='bold', fontsize=10)

plt.title('Gupta et al.', fontweight='bold', fontsize=10)
plt.ylabel('True label', fontweight='bold', fontsize=10)
plt.xlabel('Predicted label', fontweight='bold', fontsize=10)

# plt.savefig('34_fig_7a_confusion.svg', bbox_inches='tight')
plt.show()

# %%
array_7b = [[26484, 34, 2, 3, 57, 2, 0],
            [59, 1200, 0, 2, 5, 0, 2],
            [217, 2, 2613, 2, 30, 0, 0],
            [18, 4, 0, 1882, 0, 0, 0],
            [165, 5, 9, 0, 667, 0, 0],
            [4, 3, 0, 0, 0, 4, 0],
            [2, 3, 0, 0, 0, 0, 35]]


# df_cm = pd.DataFrame(array, index = [i for i in "NVRLA!E"],
#                   columns = [i for i in "NVRLA!E"])

plt.figure(figsize=(6, 6), dpi = 600)

sns.heatmap(array_7b, cmap='Blues', annot=True, xticklabels='NVRLA!E',
            yticklabels='NVRLA!E', annot_kws={"size": 10, "weight": "bold"},
            fmt='3g', square=True, linewidths=0.5, cbar_kws={"shrink": 1.0})

#plt.tick_params(axis='x', labelsize=12) # x font label size
#plt.tick_params(axis='y', labelsize=12) # y font label size

plt.yticks(fontweight='bold', fontsize=10, rotation=0)
plt.xticks(fontweight='bold', fontsize=10)

plt.title('Pokaprakarn et al.', fontweight='bold', fontsize=10)
plt.ylabel('True label', fontweight='bold', fontsize=10)
plt.xlabel('Predicted label', fontweight='bold', fontsize=10)

# plt.savefig('34_fig_7b_confusion.svg', bbox_inches='tight')
plt.show()

# %%
array_7c = [[26494, 15, 9, 12, 51, 1, 0],
            [81, 1164, 1, 12, 11, 0, 0],
            [44, 1, 2794, 5, 20, 0, 0],
            [16, 4, 0, 1884, 0, 0, 0],
            [168, 1, 10, 0, 667, 0, 0],
            [5, 2, 0, 0, 0, 4, 0],
            [4, 3, 0, 2, 0, 0, 31]]


# df_cm = pd.DataFrame(array, index = [i for i in "NVRLA!E"],
#                   columns = [i for i in "NVRLA!E"])

plt.figure(figsize=(6, 6), dpi = 600)

sns.heatmap(array_7c, cmap='Blues', annot=True, xticklabels='NVRLA!E',
            yticklabels='NVRLA!E', annot_kws={"size": 10, "weight": "bold"},
            fmt='3g', square=True, linewidths=0.5, cbar_kws={"shrink": 1.0})

#plt.tick_params(axis='x', labelsize=12) # x font label size
#plt.tick_params(axis='y', labelsize=12) # y font label size

plt.yticks(fontweight='bold', fontsize=10, rotation=0)
plt.xticks(fontweight='bold', fontsize=10)

plt.title('Sun et al.', fontweight='bold', fontsize=10)
plt.ylabel('True label', fontweight='bold', fontsize=10)
plt.xlabel('Predicted label', fontweight='bold', fontsize=10)

# plt.savefig('34_fig_7c_confusion.svg', bbox_inches='tight')
plt.show()

# %%
array_7d = [[26418, 26, 28, 3, 102, 3, 2],
         [64, 1188, 1, 2, 8, 1, 5],
         [16, 0, 2832, 3, 13, 0, 0],
         [20, 2, 0, 1882, 0, 0, 0],
         [116, 3, 13, 0, 714, 0, 0],
         [3, 3, 0, 0, 0, 5, 0],
         [0, 1, 0, 0, 0, 0, 39]]

# df_cm = pd.DataFrame(array, index = [i for i in "NVRLA!E"],
#                   columns = [i for i in "NVRLA!E"])

plt.figure(figsize=(6, 6), dpi = 600)

sns.heatmap(array_7d, cmap='Blues', annot=True, xticklabels='NVRLA!E',
            yticklabels='NVRLA!E', annot_kws={"size": 10, "weight": "bold"},
            fmt='3g', square=True, linewidths=0.5, cbar_kws={"shrink": 1.0})

#plt.tick_params(axis='x', labelsize=12) # x font label size
#plt.tick_params(axis='y', labelsize=12) # y font label size

plt.yticks(fontweight='bold', fontsize=10, rotation=0)
plt.xticks(fontweight='bold', fontsize=10)

plt.title('The proposed approach', fontweight='bold', fontsize=10)
plt.ylabel('True label', fontweight='bold', fontsize=10)
plt.xlabel('Predicted label', fontweight='bold', fontsize=10)

# plt.savefig('34_fig_7d_confusion.svg', bbox_inches='tight')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# True labels
y_true = [1, 0, 0, 1, 1, 0, 1, 0, 1, 1]

# Predicted labels
y_pred = [1, 0, 0, 1, 0, 1, 1, 1, 1, 0]

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Create a heatmap
sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['True 0', 'True 1'])

plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
