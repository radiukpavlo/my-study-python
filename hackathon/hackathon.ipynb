# %%
import pandas as pd
import os
import numpy as np

folder_path  = r'D:\dataset\dataset_uav\zeroShot_vkiit'
key_f =  os.path.join(folder_path, 'key.txt')
key_s = pd.read_csv(key_f, header=None, dtype=float, delim_whitespace=True)[0]
df = pd.DataFrame(key_s, columns=['key'])

for i in range(1, 1159):
    file_name = f'T{i:04d}.txt'
    file_path = os.path.join(folder_path, file_name)

    df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# Out:
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# ...
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]
# C:\Users\radiu\AppData\Local\Temp\ipykernel_36120\1534187276.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'T{i:04d}'] = pd.read_csv(file_path, header=None, dtype=float, delim_whitespace=True)[0]

# %%
df.head()
# Out:
#    key     T0001     T0002     T0003     T0004     T0005     T0006     T0007  \
# 0  NaN  1.145283 -0.191906 -0.151162  0.862500  1.712242  1.914885  2.582469
# 1  NaN -1.193305  0.619338  0.176902  1.251523  0.169086  0.342799  0.986709
# 2  NaN  0.323707  0.905715  1.325510 -0.037465  2.126512  1.839192 -1.393522
# 3  NaN  1.202289 -0.233818 -1.014426  1.065098  3.186039  0.924043  1.717543
# 4  NaN -0.582951  0.836221  1.375688  0.828090 -2.385756 -1.417779  0.357848
#
#       T0008     T0009  ...     T1149     T1150     T1151     T1152     T1153  \
# 0  2.393887  2.521690  ... -0.363732  0.881861 -0.271104  0.657701  0.181439
# 1  1.384582 -0.545936  ...  2.864668  0.440055  1.120082  1.784611 -0.277617
# 2  1.675406  1.621141  ... -0.684340  3.095926  3.276287 -1.901184  2.046461
# 3 -0.453127  2.031547  ...  0.584164 -1.614133  1.149012  0.635690 -0.021428
# 4  0.792018  0.307895  ...  0.298057  0.655410 -0.083779  0.351648 -1.050768
#
#       T1154     T1155     T1156     T1157     T1158
# 0  2.391281  2.746119  3.453549  1.146541 -0.073762
# 1 -0.085666 -1.330631  1.725899 -1.342670 -0.156732
# 2  0.939002  0.669606 -1.370522  2.332434 -0.582232
# 3 -0.254438  3.998092  1.630215  0.364137  1.392129
# 4  0.588836 -2.350762  1.166531 -0.819690  2.315274
#
# [5 rows x 1159 columns]

# %%
import pandas as pd


file_path = 'B:/zeroShot_vkiit/key.txt'

df = pd.read_csv(file_path, header=None, names=['value'], delimiter="\s+", skip_blank_lines=False)

df['value'] = df['value'].astype(str)

non_numeric = pd.to_numeric(df['value'], errors='coerce').isna()

empty_rows = df['value'].isna() | (df['value'].str.strip() == '')

if non_numeric.any():
    print("Є нечислові значення в файлі.")
else:
    print("Усі значення є числовими.")

if empty_rows.any():
    print("Є порожні рядки в файлі.")
else:
    print("Немає порожніх рядків.")
