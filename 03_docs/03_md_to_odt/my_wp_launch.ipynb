# %%
# Basic usage
# python md_to_odt_converter.py my_doc.md my_doc.odt --style my_company_template.odt

# # Without table of contents
# python markdown_to_docx_converter.py README.md documentation.docx --no-toc

# # With custom paths
# python markdown_to_docx_converter.py /path/to/input.md /path/to/output.docx

# %%
# Method 1: Import and use the function directly
from md_to_odt_converter import convert_md_to_odt
convert_md_to_odt('my_doc.md', 'my_doc.odt')

# Method 2: Run as script
# %run markdown_to_docx_converter.py input_markdown.md hierarchical_algorithm.docx

# Method 3: Execute with system call
# !python markdown_to_docx_converter.py input_markdown.md hierarchical_algorithm.docx
# Out:
# 📄 Reading: my_doc.md
# 🚀 Converting to OpenDocument Text...
# [WARNING] Could not fetch resource figs/72_fig_1.png: PandocResourceNotFound "figs/72_fig_1.png"
# [WARNING] Could not fetch resource figs/results_seg_boxplots.pdf: PandocResourceNotFound "figs/results_seg_boxplots.pdf"
# [WARNING] Could not fetch resource figs/results_seg_macro_bars.pdf: PandocResourceNotFound "figs/results_seg_macro_bars.pdf"
# [WARNING] Could not fetch resource figs/results_domain_shift.pdf: PandocResourceNotFound "figs/results_domain_shift.pdf"
# [WARNING] Could not fetch resource figs/results_roc_curve.pdf: PandocResourceNotFound "figs/results_roc_curve.pdf"
# [WARNING] Could not fetch resource figs/results_pr_curve.pdf: PandocResourceNotFound "figs/results_pr_curve.pdf"
# [WARNING] Could not fetch resource figs/results_confusion_matrix.pdf: PandocResourceNotFound "figs/results_confusion_matrix.pdf"
# [WARNING] Could not fetch resource figs/results_reliability_pre_post.pdf: PandocResourceNotFound "figs/results_reliability_pre_post.pdf"
# [WARNING] Could not fetch resource figs/results_throughput_batch.pdf: PandocResourceNotFound "figs/results_throughput_batch.pdf"
# [WARNING] Could not fetch resource figs/Appendix_Fig1.pdf: PandocResourceNotFound "figs/Appendix_Fig1.pdf"
# [WARNING] Could not fetch resource figs/Appendix_Fig2.pdf: PandocResourceNotFound "figs/Appendix_Fig2.pdf"
# [WARNING] Could not fetch resource figs/Appendix_Fig3.pdf: PandocResourceNotFound "figs/Appendix_Fig3.pdf"
# [WARNING] Could not fetch resource figs/Appendix_Fig4.pdf: PandocResourceNotFound "figs/Appendix_Fig4.pdf"
# [WARNING] Could not fetch resource figs/Appendix_Fig5.pdf: PandocResourceNotFound "figs/Appendix_Fig5.pdf"
# ✅ Success! File saved to:
#    D:\GitHub\my-study-python\03_docs\03_md_to_odt\my_doc.odt
