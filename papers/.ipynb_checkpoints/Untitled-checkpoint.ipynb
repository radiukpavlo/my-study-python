# %%
import matplotlib.pyplot as plt

# Create a list (or array) of x-values.
x_values = [1, 2, 3, 4, 5]

# Create a list (or array) of y-values.
y_values = [2, 4, 1, 5, 7]

# Plot y-values against x-values.
plt.plot(x_values, y_values)

# Show the plot.
plt.show()
